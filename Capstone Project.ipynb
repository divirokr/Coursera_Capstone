# %% [markdown]
# ## Problem Description

# %% [markdown]
# Toronto, being among the top destination for Indian immigrants, has a lot of scope for Indian Restaurants. We analyze the neighborhoods in Toronto to identify the most profitable area since the success of the restaurant depends on the people who would be visiting the restaurants.
#
# However, keeping in mind the competition, we will try to narrow down to a particular riding.
#
# The focus would be on the 2 aspects -
#
# Riding with high number of Indian Population and Riding with a least number of Indian Restaurants currently

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data which has been used along with the sources -
#
# a) “List of Postal code of Canada: M” (https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M) wiki page to get all the information about the neighborhoods present in Toronto. This page has the postal code, borough & the name of all the neighborhoods present in Toronto.
#
# b)  “https://cocl.us/Geospatial_data” csv file to get all the geographical coordinates of the neighborhoods.
#
# c) “Demographics of Toronto” (https://en.m.wikipedia.org/wiki/Demographics_of_Toronto#Ethnic_diversity) wiki page to fetch data regarding Indian Population at various neighborhoods.
#
# d) Foursquare API (which gives venues recommendations), to get the details like Venue names, categories, Latitude, Longitude details of existing places to visit.

# %% [markdown]
# #### Segmenting and Clustering Neighborhoods in Toronto

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlopen

# %%
conda install -c anaconda beautifulsoup4
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     numpy-base-1.15.4          |   py36h81de0dd_0         4.2 MB  anaconda
#     numpy-1.15.4               |   py36h1d66e8a_0          35 KB  anaconda
#     beautifulsoup4-4.8.1       |           py36_0         153 KB  anaconda
#     openssl-1.1.1              |       h7b6447c_0         5.0 MB  anaconda
#     soupsieve-1.9.5            |           py36_0          61 KB  anaconda
#     mkl_fft-1.0.6              |   py36h7dd41cf_0         150 KB  anaconda
#     certifi-2019.11.28         |           py36_0         156 KB  anaconda
#     blas-1.0                   |              mkl           6 KB  anaconda
#     scipy-1.1.0                |   py36hfa4b5c9_1        18.0 MB  anaconda
#     mkl_random-1.0.1           |   py36h4414c95_1         373 KB  anaconda
#     scikit-learn-0.20.1        |   py36h4989274_0         5.7 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:        33.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     soupsieve:      1.9.5-py36_0                           anaconda
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.6.3-py37_0                                       --> 4.8.1-py36_0          anaconda
#     certifi:        2019.9.11-py36_0                       conda-forge --> 2019.11.28-py36_0     anaconda
#     mkl_fft:        1.0.4-py37h4414c95_1                               --> 1.0.6-py36h7dd41cf_0  anaconda
#     mkl_random:     1.0.1-py37h4414c95_1                               --> 1.0.1-py36h4414c95_1  anaconda
#     numpy-base:     1.15.1-py37h81de0dd_0                              --> 1.15.4-py36h81de0dd_0 anaconda
#     openssl:        1.1.1d-h516909a_0                      conda-forge --> 1.1.1-h7b6447c_0      anaconda
#
# The following packages will be DOWNGRADED:
#
#     blas:           1.1-openblas                           conda-forge --> 1.0-mkl               anaconda
#     numpy:          1.16.2-py36_blas_openblash1522bff_0    conda-forge [blas_openblas] --> 1.15.4-py36h1d66e8a_0 anaconda
#     scikit-learn:   0.20.1-py36_blas_openblashebff5e3_1200 conda-forge [blas_openblas] --> 0.20.1-py36h4989274_0 anaconda
#     scipy:          1.2.1-py36_blas_openblash1522bff_0     conda-forge [blas_openblas] --> 1.1.0-py36hfa4b5c9_1  anaconda
#
#
# Downloading and Extracting Packages
# numpy-base-1.15.4    | 4.2 MB    | ##################################### | 100%
# numpy-1.15.4         | 35 KB     | ##################################### | 100%
# beautifulsoup4-4.8.1 | 153 KB    | ##################################### | 100%
# openssl-1.1.1        | 5.0 MB    | ##################################### | 100%
# soupsieve-1.9.5      | 61 KB     | ##################################### | 100%
# mkl_fft-1.0.6        | 150 KB    | ##################################### | 100%
# certifi-2019.11.28   | 156 KB    | ##################################### | 100%
# blas-1.0             | 6 KB      | ##################################### | 100%
# scipy-1.1.0          | 18.0 MB   | ##################################### | 100%
# mkl_random-1.0.1     | 373 KB    | ##################################### | 100%
# scikit-learn-0.20.1  | 5.7 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install geopy
# Out:
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/80/93/d384479da0ead712bdaf697a8399c13a9a89bd856ada5a27d462fb45e47b/geopy-1.20.0-py2.py3-none-any.whl (100kB)
#      |████████████████████████████████| 102kB 8.5MB/s ta 0:00:011
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-1.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/68/30/affd16b77edf9537f5be051905f33527021e20d563d013e8c42c7fd01949/lxml-4.4.2-cp36-cp36m-manylinux1_x86_64.whl (5.8MB)
#      |████████████████████████████████| 5.8MB 7.6MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
from bs4 import BeautifulSoup
import lxml
print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# download data and parse it:
r = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
soup = BeautifulSoup(r.text, 'html.parser')
table=soup.find('table', attrs={'class':'wikitable sortable'})

#get headers:
headers=table.findAll('th')
for i, head in enumerate(headers): headers[i]=str(headers[i]).replace("<th>","").replace("</th>","").replace("\n","")

#Find all items and skip first one:
rows=table.findAll('tr')
rows=rows[1:len(rows)]

# skip all meta symbols and line feeds between rows:
for i, row in enumerate(rows): rows[i] = str(rows[i]).replace("\n</td></tr>","").replace("<tr>\n<td>","")

# make dataframe, expand rows and drop the old one:
df=pd.DataFrame(rows)
df[headers] = df[0].str.split("</td>\n<td>", n = 2, expand = True) 
df.drop(columns=[0],inplace=True)

# skip not assigned boroughs:
df = df.drop(df[(df.Borough == "Not assigned")].index)
# give "Not assigned" Neighborhoods same name as Borough:
df.Neighborhood.replace("Not assigned", df.Borough, inplace=True)

# copy Borough value to Neighborhood if NaN:
df.Neighborhood.fillna(df.Borough, inplace=True)
# drop duplicate rows:
df=df.drop_duplicates()

# extract titles from columns
df.update(
    df.Neighborhood.loc[
        lambda x: x.str.contains('title')
    ].str.extract('title=\"([^\"]*)',expand=False))

df.update(
    df.Borough.loc[
        lambda x: x.str.contains('title')
    ].str.extract('title=\"([^\"]*)',expand=False))

# delete Toronto annotation from Neighbourhood:
df.update(
    df.Neighborhood.loc[
        lambda x: x.str.contains('Toronto')
    ].str.replace(", Toronto",""))
df.update(
    df.Neighborhood.loc[
        lambda x: x.str.contains('Toronto')
    ].str.replace("\(Toronto\)",""))

# combine multiple neighborhoods with the same post code
df2 = pd.DataFrame({'Postcode':df.Postcode.unique()})
df2['Borough']=pd.DataFrame(list(set(df['Borough'].loc[df['Postcode'] == x['Postcode']])) for i, x in df2.iterrows())
df2['Neighborhood']=pd.Series(list(set(df['Neighborhood'].loc[df['Postcode'] == x['Postcode']])) for i, x in df2.iterrows())
df2['Neighborhood']=df2['Neighborhood'].apply(lambda x: ', '.join(x))
df2.dtypes

df2.head(12)
# Out:
#    Postcode                 Borough  \
# 0       M3A              North York
# 1       M4A              North York
# 2       M5A        Downtown Toronto
# 3       M6A              North York
# 4       M7A        Downtown Toronto
# 5       M9A  Queen's Park (Toronto)
# 6       M1B    Scarborough, Toronto
# 7       M3B              North York
# 8       M4B               East York
# 9       M5B        Downtown Toronto
# 10      M6B              North York
# 11      M9B               Etobicoke
#
#                                          Neighborhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                                         Regent Park
# 3                    Lawrence Manor, Lawrence Heights
# 4                                       Queen's Park
# 5                                       Queen's Park
# 6                                      Malvern, Rouge
# 7                                     Don Mills North
# 8                     Woodbine Gardens, Parkview Hill
# 9                            Ryerson, Garden District
# 10                                          Glencairn
# 11  Princess Gardens, West Deane Park, Martin Grov...

# %%
df2.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Geocoding

# %%
dfll= pd.read_csv("http://cocl.us/Geospatial_data")
dfll.rename(columns={'Postal Code':'Postcode'}, inplace=True)
dfll.set_index("Postcode")
df2.set_index("Postcode")
toronto_data=pd.merge(df2, dfll)
toronto_data.head(12)
# Out:
#    Postcode                 Borough  \
# 0       M3A              North York
# 1       M4A              North York
# 2       M5A        Downtown Toronto
# 3       M6A              North York
# 4       M7A        Downtown Toronto
# 5       M9A  Queen's Park (Toronto)
# 6       M1B    Scarborough, Toronto
# 7       M3B              North York
# 8       M4B               East York
# 9       M5B        Downtown Toronto
# 10      M6B              North York
# 11      M9B               Etobicoke
#
#                                          Neighborhood   Latitude  Longitude
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                    Victoria Village  43.725882 -79.315572
# 2                                         Regent Park  43.654260 -79.360636
# 3                    Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4                                       Queen's Park   43.662301 -79.389494
# 5                                       Queen's Park   43.667856 -79.532242
# 6                                      Malvern, Rouge  43.806686 -79.194353
# 7                                     Don Mills North  43.745906 -79.352188
# 8                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                            Ryerson, Garden District  43.657162 -79.378937
# 10                                          Glencairn  43.709577 -79.445073
# 11  Princess Gardens, West Deane Park, Martin Grov...  43.650943 -79.554724

# %%
address = 'Toronto, ON, Canada'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto, ON, Canada are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto, ON, Canada are 43.653963, -79.387207.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'RYVIU3ZI44PMCW4XVH0053XSXEUQ4Y3FM0LS44U2AGS2KULM' # your Foursquare ID
CLIENT_SECRET = 'TFKDCAHI3KWMU0P2Z1PRVYMX1OACUE5JRQZ2B5TE3AZPTU3D' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RYVIU3ZI44PMCW4XVH0053XSXEUQ4Y3FM0LS44U2AGS2KULM
# CLIENT_SECRET:TFKDCAHI3KWMU0P2Z1PRVYMX1OACUE5JRQZ2B5TE3AZPTU3D

# %%
toronto_data.loc[0, 'Neighborhood']
# Out:
# 'Parkwoods'

# %%
neighborhood_latitude = toronto_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = toronto_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = toronto_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Parkwoods are 43.7532586, -79.3296565.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=RYVIU3ZI44PMCW4XVH0053XSXEUQ4Y3FM0LS44U2AGS2KULM&client_secret=TFKDCAHI3KWMU0P2Z1PRVYMX1OACUE5JRQZ2B5TE3AZPTU3D&v=20180605&ll=43.7532586,-79.3296565&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e0f21843907e7001b6f1fab'},
#  'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."},
#   'headerLocation': 'Parkwoods - Donalda',
#   'headerFullLocation': 'Parkwoods - Donalda, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 3,
#   'suggestedBounds': {'ne': {'lat': 43.757758604500005,
#     'lng': -79.32343823984928},
#    'sw': {'lat': 43.7487585955, 'lng': -79.33587476015072}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8d9dcdd5fbbbb6b3003c7b',
#        'name': 'Brookbanks Park',
#        'location': {'address': 'Toronto',
#         'lat': 43.751976046055574,
#         'lng': -79.33214044722958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.751976046055574,
#           'lng': -79.33214044722958}],
#         'distance': 245,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8d9dcdd5fbbbb6b3003c7b-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb11e2075ebb60cd1c4caad',
#        'name': 'Variety Store',
#        'location': {'address': '29 Valley Woods Road',
#         'lat': 43.75197441585782,
#         'lng': -79.33311418516017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75197441585782,
#           'lng': -79.33311418516017}],
#         'distance': 312,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['29 Valley Woods Road', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f9941735',
#          'name': 'Food & Drink Shop',
#          'pluralName': 'Food & Drink Shops',
#          'shortName': 'Food & Drink',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb11e2075ebb60cd1c4caad-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5921cc82e96d0c63d980640c',
#        'name': 'Corrosion Service Company Limited',
#        'location': {'address': '9-280 Hillmount Rd.',
#         'lat': 43.75243208667859,
#         'lng': -79.33466148402658,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75243208667859,
#           'lng': -79.33466148402658}],
#         'distance': 412,
#         'postalCode': 'L6C 3A1',
#         'cc': 'CA',
#         'city': 'Markham',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['9-280 Hillmount Rd.',
#          'Markham ON L6C 3A1',
#          'Canada']},
#        'categories': [{'id': '5454144b498ec1f095bff2f2',
#          'name': 'Construction & Landscaping',
#          'pluralName': 'Construction & Landscaping',
#          'shortName': 'Construction',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5921cc82e96d0c63d980640c-2'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                                 name                  categories        lat  \
# 0                    Brookbanks Park                        Park  43.751976
# 1                      Variety Store           Food & Drink Shop  43.751974
# 2  Corrosion Service Company Limited  Construction & Landscaping  43.752432
#
#          lng
# 0 -79.332140
# 1 -79.333114
# 2 -79.334661

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 3 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# Parkwoods
# Victoria Village
# Regent Park
# Lawrence Manor, Lawrence Heights
# Queen's Park
# Queen's Park
# Malvern, Rouge
# Don Mills North
# Woodbine Gardens, Parkview Hill
# Ryerson, Garden District
# Glencairn
# Princess Gardens, West Deane Park, Martin Grove, Islington, Cloverdale
# Highland Creek , Rouge Hill, Port Union
# Don Mills South, Flemingdon Park
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Markland Wood, Old Burnhamthorpe, Bloordale Gardens, Eringate
# Morningside, Guildwood, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Downsview North, Wilson Heights, Bathurst Manor
# Thorncliffe Park
# Adelaide, Richmond, King
# Dovercourt Village, Dufferin
# Scarborough Village
# Fairview, Oriole, Henry Farm
# Northwood Park, York University
# East Toronto
# Union Station , Harbourfront East, Toronto Islands
# Little Portugal, Trinity–Bellwoods
# Ionview, Kennedy Park, East Birchmount Park
# Bayview Village
# CFB Toronto, Downsview East
# Riverdale, The Danforth West
# Design Exchange, Toronto Dominion Centre
# Exhibition Place, Parkdale Village, Brockton
# Golden Mile, Clairlea, Oakridge
# Silver Hills, York Mills
# Downsview
# The Beaches West, India Bazaar
# Commerce Court, Victoria Hotel
# Upwood Park, North Park, Downsview
# Humber Summit
# Cliffside, Scarborough Village West, Cliffcrest
# Willowdale, Newtonbrook
# Downsview Central
# Studio District
# Bedford Park, Lawrence Manor East
# Silverthorn, Mount Dennis, Keelesdale, Del Ray
# Emery, Humberlea
# Cliffside West, Birch Cliff
# Willowdale South
# Downsview Northwest
# Lawrence Park
# Roselawn
# The Junction North, Runnymede
# Weston
# Scarborough Town Centre, Wexford Heights, Dorset Park
# York Mills West
# Davisville North
# Forest Hill West, Forest Hill North
# High Park, The Junction South
# Westmount
# Wexford, Maryvale
# Willowdale West
# North Toronto West
# Yorkville, The Annex, North Midtown
# Parkdale, Roncesvalles
# Canada Post Gateway Processing Centre
# Richview Gardens, Kingsview Village, St. Phillips, Martin Grove Gardens
# Agincourt
# Davisville
# University of Toronto, Harbord
# Swansea, Runnymede
# Sullivan, Tam O'Shanter – Sullivan, Clarks Corners
# Summerhill East, Moore Park
# Grange Park , Kensington Market, Chinatown
# Agincourt North, Steeles East, L'Amoreaux East, Milliken, Ontario
# Summerhill West, Forest Hill SE, Deer Park, South Hill, Rathnelly
# South Niagara, Bathurst Quay, King and Spadina, Railway Lands, CN Tower, Harbourfront West, Island airport
# Mimico South, New Toronto, Humber Bay Shores
# Mount Olive-Silverstone-Jamestown, South Steeles, Thistletown, Silverstone, Beaumond Heights, Albion Gardens, Humbergate
# L'Amoreaux West
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Alderwood, Long Branch
# Northwest
# Upper Rouge
# St. James Town, Cabbagetown
# Underground city, First Canadian Place
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern
# Old Mill, Sunnylea, Kingsway Park South East, Fairmont Royal York Hotel, Humber Bay, The Queensway, Mimico, King's Mill Park
# Kingsway Park South West, Royal York South West, The Queensway, South of Bloor, Mimico

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (2227, 7)
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0         Parkwoods              43.753259              -79.329656
# 1         Parkwoods              43.753259              -79.329656
# 2         Parkwoods              43.753259              -79.329656
# 3  Victoria Village              43.725882              -79.315572
# 4  Victoria Village              43.725882              -79.315572
#
#                                Venue  Venue Latitude  Venue Longitude  \
# 0                    Brookbanks Park       43.751976       -79.332140
# 1                      Variety Store       43.751974       -79.333114
# 2  Corrosion Service Company Limited       43.752432       -79.334661
# 3             Victoria Village Arena       43.723481       -79.315635
# 4                        Tim Hortons       43.725517       -79.313103
#
#                Venue Category
# 0                        Park
# 1           Food & Drink Shop
# 2  Construction & Landscaping
# 3                Hockey Arena
# 4                 Coffee Shop

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Adelaide, Richmond, King                                              100
# Agincourt                                                               5
# Agincourt North, Steeles East, L'Amoreaux East,...                      4
# Alderwood, Long Branch                                                 10
# Bayview Village                                                         4
# Bedford Park, Lawrence Manor East                                      22
# Berczy Park                                                            56
# Business Reply Mail Processing Centre 969 Eastern                      17
# CFB Toronto, Downsview East                                             2
# Caledonia-Fairbanks                                                     5
# Canada Post Gateway Processing Centre                                  10
# Cedarbrae                                                               8
# Central Bay Street                                                     86
# Christie                                                               18
# Church and Wellesley                                                   86
# Cliffside West, Birch Cliff                                             4
# Cliffside, Scarborough Village West, Cliffcrest                         3
# Commerce Court, Victoria Hotel                                        100
# Davisville                                                             33
# Davisville North                                                        8
# Design Exchange, Toronto Dominion Centre                              100
# Don Mills North                                                         5
# Don Mills South, Flemingdon Park                                       22
# Dovercourt Village, Dufferin                                           17
# Downsview                                                               6
# Downsview Central                                                       3
# Downsview North, Wilson Heights, Bathurst Manor                        20
# Downsview Northwest                                                     5
# East Toronto                                                            3
# Emery, Humberlea                                                        1
# Exhibition Place, Parkdale Village, Brockton                           21
# Fairview, Oriole, Henry Farm                                           62
# Forest Hill West, Forest Hill North                                     4
# Glencairn                                                               4
# Golden Mile, Clairlea, Oakridge                                         9
# Grange Park , Kensington Market, Chinatown                             90
# High Park, The Junction South                                          24
# Highland Creek , Rouge Hill, Port Union                                 2
# Hillcrest Village                                                       5
# Humber Summit                                                           2
# Humewood-Cedarvale                                                      5
# Ionview, Kennedy Park, East Birchmount Park                             7
# Kingsway Park South West, Royal York South West...                     14
# L'Amoreaux West                                                        14
# Lawrence Manor, Lawrence Heights                                        8
# Lawrence Park                                                           3
# Leaside                                                                33
# Little Portugal, Trinity–Bellwoods                                     55
# Malvern, Rouge                                                          2
# Markland Wood, Old Burnhamthorpe, Bloordale Gar...                      7
# Mimico South, New Toronto, Humber Bay Shores                           13
# Morningside, Guildwood, West Hill                                       7
# Mount Olive-Silverstone-Jamestown, South Steele...                      9
# North Toronto West                                                     21
# Northwest                                                               2
# Northwood Park, York University                                         5
# Old Mill, Sunnylea, Kingsway Park South East, F...                      1
# Parkdale, Roncesvalles                                                 13
# Parkwoods                                                               3
# Princess Gardens, West Deane Park, Martin Grove...                      1
# Queen's Park                                                           38
# Regent Park                                                            48
# Richview Gardens, Kingsview Village, St. Philli...                      4
# Riverdale, The Danforth West                                           42
# Rosedale                                                                4
# Roselawn                                                                2
# Ryerson, Garden District                                              100
# Scarborough Town Centre, Wexford Heights, Dorse...                      6
# Scarborough Village                                                     2
# Silver Hills, York Mills                                                1
# Silverthorn, Mount Dennis, Keelesdale, Del Ray                          5
# South Niagara, Bathurst Quay, King and Spadina,...                     16
# St. James Town                                                        100
# St. James Town, Cabbagetown                                            44
# Stn A PO Boxes 25 The Esplanade                                        97
# Studio District                                                        41
# Sullivan, Tam O'Shanter – Sullivan, Clarks Corners                     11
# Summerhill East, Moore Park                                             4
# Summerhill West, Forest Hill SE, Deer Park, Sou...                     16
# Swansea, Runnymede                                                     33
# The Beaches                                                             4
# The Beaches West, India Bazaar                                         22
# The Junction North, Runnymede                                           4
# The Kingsway, Montgomery Road, Old Mill North                           3
# Thorncliffe Park                                                       18
# Underground city, First Canadian Place                                100
# Union Station , Harbourfront East, Toronto Islands                    100
# University of Toronto, Harbord                                         38
# Upwood Park, North Park, Downsview                                      5
# Victoria Village                                                        4
# Westmount                                                               7
# Weston                                                                  1
# Wexford, Maryvale                                                       4
# Willowdale South                                                       35
# Willowdale West                                                         6
# Woburn                                                                  4
# Woodbine Gardens, Parkview Hill                                        12
# Woodbine Heights                                                       11
# York Mills West                                                         4
# Yorkville, The Annex, North Midtown                                    22
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Adelaide, Richmond, King                                               100
# Agincourt                                                                5
# Agincourt North, Steeles East, L'Amoreaux East,...                       4
# Alderwood, Long Branch                                                  10
# Bayview Village                                                          4
# Bedford Park, Lawrence Manor East                                       22
# Berczy Park                                                             56
# Business Reply Mail Processing Centre 969 Eastern                       17
# CFB Toronto, Downsview East                                              2
# Caledonia-Fairbanks                                                      5
# Canada Post Gateway Processing Centre                                   10
# Cedarbrae                                                                8
# Central Bay Street                                                      86
# Christie                                                                18
# Church and Wellesley                                                    86
# Cliffside West, Birch Cliff                                              4
# Cliffside, Scarborough Village West, Cliffcrest                          3
# Commerce Court, Victoria Hotel                                         100
# Davisville                                                              33
# Davisville North                                                         8
# Design Exchange, Toronto Dominion Centre                               100
# Don Mills North                                                          5
# Don Mills South, Flemingdon Park                                        22
# Dovercourt Village, Dufferin                                            17
# Downsview                                                                6
# Downsview Central                                                        3
# Downsview North, Wilson Heights, Bathurst Manor                         20
# Downsview Northwest                                                      5
# East Toronto                                                             3
# Emery, Humberlea                                                         1
# Exhibition Place, Parkdale Village, Brockton                            21
# Fairview, Oriole, Henry Farm                                            62
# Forest Hill West, Forest Hill North                                      4
# Glencairn                                                                4
# Golden Mile, Clairlea, Oakridge                                          9
# Grange Park , Kensington Market, Chinatown                              90
# High Park, The Junction South                                           24
# Highland Creek , Rouge Hill, Port Union                                  2
# Hillcrest Village                                                        5
# Humber Summit                                                            2
# Humewood-Cedarvale                                                       5
# Ionview, Kennedy Park, East Birchmount Park                              7
# Kingsway Park South West, Royal York South West...                      14
# L'Amoreaux West                                                         14
# Lawrence Manor, Lawrence Heights                                         8
# Lawrence Park                                                            3
# Leaside                                                                 33
# Little Portugal, Trinity–Bellwoods                                      55
# Malvern, Rouge                                                           2
# Markland Wood, Old Burnhamthorpe, Bloordale Gar...                       7
# Mimico South, New Toronto, Humber Bay Shores                            13
# Morningside, Guildwood, West Hill                                        7
# Mount Olive-Silverstone-Jamestown, South Steele...                       9
# North Toronto West                                                      21
# Northwest                                                                2
# Northwood Park, York University                                          5
# Old Mill, Sunnylea, Kingsway Park South East, F...                       1
# Parkdale, Roncesvalles                                                  13
# Parkwoods                                                                3
# Princess Gardens, West Deane Park, Martin Grove...                       1
# Queen's Park                                                            38
# Regent Park                                                             48
# Richview Gardens, Kingsview Village, St. Philli...                       4
# Riverdale, The Danforth West                                            42
# Rosedale                                                                 4
# Roselawn                                                                 2
# Ryerson, Garden District                                               100
# Scarborough Town Centre, Wexford Heights, Dorse...                       6
# Scarborough Village                                                      2
# Silver Hills, York Mills                                                 1
# Silverthorn, Mount Dennis, Keelesdale, Del Ray                           5
# South Niagara, Bathurst Quay, King and Spadina,...                      16
# St. James Town                                                         100
# St. James Town, Cabbagetown                                             44
# Stn A PO Boxes 25 The Esplanade                                         97
# Studio District                                                         41
# Sullivan, Tam O'Shanter – Sullivan, Clarks Corners                      11
# Summerhill East, Moore Park                                              4
# Summerhill West, Forest Hill SE, Deer Park, Sou...                      16
# Swansea, Runnymede                                                      33
# The Beaches                                                              4
# The Beaches West, India Bazaar                                          22
# The Junction North, Runnymede                                            4
# The Kingsway, Montgomery Road, Old Mill North                            3
# Thorncliffe Park                                                        18
# Underground city, First Canadian Place                                 100
# Union Station , Harbourfront East, Toronto Islands                     100
# University of Toronto, Harbord                                          38
# Upwood Park, North Park, Downsview                                       5
# Victoria Village                                                         4
# Westmount                                                                7
# Weston                                                                   1
# Wexford, Maryvale                                                        4
# Willowdale South                                                        35
# Willowdale West                                                          6
# Woburn                                                                   4
# Woodbine Gardens, Parkview Hill                                         12
# Woodbine Heights                                                        11
# York Mills West                                                          4
# Yorkville, The Annex, North Midtown                                     22
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Adelaide, Richmond, King                              100             100
# Agincourt                                               5               5
# Agincourt North, Steeles East, L'Amoreaux East,...      4               4
# Alderwood, Long Branch                                 10              10
# Bayview Village                                         4               4
# Bedford Park, Lawrence Manor East                      22              22
# Berczy Park                                            56              56
# Business Reply Mail Processing Centre 969 Eastern      17              17
# CFB Toronto, Downsview East                             2               2
# Caledonia-Fairbanks                                     5               5
# Canada Post Gateway Processing Centre                  10              10
# Cedarbrae                                               8               8
# Central Bay Street                                     86              86
# Christie                                               18              18
# Church and Wellesley                                   86              86
# Cliffside West, Birch Cliff                             4               4
# Cliffside, Scarborough Village West, Cliffcrest         3               3
# Commerce Court, Victoria Hotel                        100             100
# Davisville                                             33              33
# Davisville North                                        8               8
# Design Exchange, Toronto Dominion Centre              100             100
# Don Mills North                                         5               5
# Don Mills South, Flemingdon Park                       22              22
# Dovercourt Village, Dufferin                           17              17
# Downsview                                               6               6
# Downsview Central                                       3               3
# Downsview North, Wilson Heights, Bathurst Manor        20              20
# Downsview Northwest                                     5               5
# East Toronto                                            3               3
# Emery, Humberlea                                        1               1
# Exhibition Place, Parkdale Village, Brockton           21              21
# Fairview, Oriole, Henry Farm                           62              62
# Forest Hill West, Forest Hill North                     4               4
# Glencairn                                               4               4
# Golden Mile, Clairlea, Oakridge                         9               9
# Grange Park , Kensington Market, Chinatown             90              90
# High Park, The Junction South                          24              24
# Highland Creek , Rouge Hill, Port Union                 2               2
# Hillcrest Village                                       5               5
# Humber Summit                                           2               2
# Humewood-Cedarvale                                      5               5
# Ionview, Kennedy Park, East Birchmount Park             7               7
# Kingsway Park South West, Royal York South West...     14              14
# L'Amoreaux West                                        14              14
# Lawrence Manor, Lawrence Heights                        8               8
# Lawrence Park                                           3               3
# Leaside                                                33              33
# Little Portugal, Trinity–Bellwoods                     55              55
# Malvern, Rouge                                          2               2
# Markland Wood, Old Burnhamthorpe, Bloordale Gar...      7               7
# Mimico South, New Toronto, Humber Bay Shores           13              13
# Morningside, Guildwood, West Hill                       7               7
# Mount Olive-Silverstone-Jamestown, South Steele...      9               9
# North Toronto West                                     21              21
# Northwest                                               2               2
# Northwood Park, York University                         5               5
# Old Mill, Sunnylea, Kingsway Park South East, F...      1               1
# Parkdale, Roncesvalles                                 13              13
# Parkwoods                                               3               3
# Princess Gardens, West Deane Park, Martin Grove...      1               1
# Queen's Park                                           38              38
# Regent Park                                            48              48
# Richview Gardens, Kingsview Village, St. Philli...      4               4
# Riverdale, The Danforth West                           42              42
# Rosedale                                                4               4
# Roselawn                                                2               2
# Ryerson, Garden District                              100             100
# Scarborough Town Centre, Wexford Heights, Dorse...      6               6
# Scarborough Village                                     2               2
# Silver Hills, York Mills                                1               1
# Silverthorn, Mount Dennis, Keelesdale, Del Ray          5               5
# South Niagara, Bathurst Quay, King and Spadina,...     16              16
# St. James Town                                        100             100
# St. James Town, Cabbagetown                            44              44
# Stn A PO Boxes 25 The Esplanade                        97              97
# Studio District                                        41              41
# Sullivan, Tam O'Shanter – Sullivan, Clarks Corners     11              11
# Summerhill East, Moore Park                             4               4
# Summerhill West, Forest Hill SE, Deer Park, Sou...     16              16
# Swansea, Runnymede                                     33              33
# The Beaches                                             4               4
# The Beaches West, India Bazaar                         22              22
# The Junction North, Runnymede                           4               4
# The Kingsway, Montgomery Road, Old Mill North           3               3
# Thorncliffe Park                                       18              18
# Underground city, First Canadian Place                100             100
# Union Station , Harbourfront East, Toronto Islands    100             100
# University of Toronto, Harbord                         38              38
# Upwood Park, North Park, Downsview                      5               5
# Victoria Village                                        4               4
# Westmount                                               7               7
# Weston                                                  1               1
# Wexford, Maryvale                                       4               4
# Willowdale South                                       35              35
# Willowdale West                                         6               6
# Woburn                                                  4               4
# Woodbine Gardens, Parkview Hill                        12              12
# Woodbine Heights                                       11              11
# York Mills West                                         4               4
# Yorkville, The Annex, North Midtown                    22              22
#
#                                                     Venue Longitude  \
# Neighborhood
# Adelaide, Richmond, King                                        100
# Agincourt                                                         5
# Agincourt North, Steeles East, L'Amoreaux East,...                4
# Alderwood, Long Branch                                           10
# Bayview Village                                                   4
# Bedford Park, Lawrence Manor East                                22
# Berczy Park                                                      56
# Business Reply Mail Processing Centre 969 Eastern                17
# CFB Toronto, Downsview East                                       2
# Caledonia-Fairbanks                                               5
# Canada Post Gateway Processing Centre                            10
# Cedarbrae                                                         8
# Central Bay Street                                               86
# Christie                                                         18
# Church and Wellesley                                             86
# Cliffside West, Birch Cliff                                       4
# Cliffside, Scarborough Village West, Cliffcrest                   3
# Commerce Court, Victoria Hotel                                  100
# Davisville                                                       33
# Davisville North                                                  8
# Design Exchange, Toronto Dominion Centre                        100
# Don Mills North                                                   5
# Don Mills South, Flemingdon Park                                 22
# Dovercourt Village, Dufferin                                     17
# Downsview                                                         6
# Downsview Central                                                 3
# Downsview North, Wilson Heights, Bathurst Manor                  20
# Downsview Northwest                                               5
# East Toronto                                                      3
# Emery, Humberlea                                                  1
# Exhibition Place, Parkdale Village, Brockton                     21
# Fairview, Oriole, Henry Farm                                     62
# Forest Hill West, Forest Hill North                               4
# Glencairn                                                         4
# Golden Mile, Clairlea, Oakridge                                   9
# Grange Park , Kensington Market, Chinatown                       90
# High Park, The Junction South                                    24
# Highland Creek , Rouge Hill, Port Union                           2
# Hillcrest Village                                                 5
# Humber Summit                                                     2
# Humewood-Cedarvale                                                5
# Ionview, Kennedy Park, East Birchmount Park                       7
# Kingsway Park South West, Royal York South West...               14
# L'Amoreaux West                                                  14
# Lawrence Manor, Lawrence Heights                                  8
# Lawrence Park                                                     3
# Leaside                                                          33
# Little Portugal, Trinity–Bellwoods                               55
# Malvern, Rouge                                                    2
# Markland Wood, Old Burnhamthorpe, Bloordale Gar...                7
# Mimico South, New Toronto, Humber Bay Shores                     13
# Morningside, Guildwood, West Hill                                 7
# Mount Olive-Silverstone-Jamestown, South Steele...                9
# North Toronto West                                               21
# Northwest                                                         2
# Northwood Park, York University                                   5
# Old Mill, Sunnylea, Kingsway Park South East, F...                1
# Parkdale, Roncesvalles                                           13
# Parkwoods                                                         3
# Princess Gardens, West Deane Park, Martin Grove...                1
# Queen's Park                                                     38
# Regent Park                                                      48
# Richview Gardens, Kingsview Village, St. Philli...                4
# Riverdale, The Danforth West                                     42
# Rosedale                                                          4
# Roselawn                                                          2
# Ryerson, Garden District                                        100
# Scarborough Town Centre, Wexford Heights, Dorse...                6
# Scarborough Village                                               2
# Silver Hills, York Mills                                          1
# Silverthorn, Mount Dennis, Keelesdale, Del Ray                    5
# South Niagara, Bathurst Quay, King and Spadina,...               16
# St. James Town                                                  100
# St. James Town, Cabbagetown                                      44
# Stn A PO Boxes 25 The Esplanade                                  97
# Studio District                                                  41
# Sullivan, Tam O'Shanter – Sullivan, Clarks Corners               11
# Summerhill East, Moore Park                                       4
# Summerhill West, Forest Hill SE, Deer Park, Sou...               16
# Swansea, Runnymede                                               33
# The Beaches                                                       4
# The Beaches West, India Bazaar                                   22
# The Junction North, Runnymede                                     4
# The Kingsway, Montgomery Road, Old Mill North                     3
# Thorncliffe Park                                                 18
# Underground city, First Canadian Place                          100
# Union Station , Harbourfront East, Toronto Islands              100
# University of Toronto, Harbord                                   38
# Upwood Park, North Park, Downsview                                5
# Victoria Village                                                  4
# Westmount                                                         7
# Weston                                                            1
# Wexford, Maryvale                                                 4
# Willowdale South                                                 35
# Willowdale West                                                   6
# Woburn                                                            4
# Woodbine Gardens, Parkview Hill                                  12
# Woodbine Heights                                                 11
# York Mills West                                                   4
# Yorkville, The Annex, North Midtown                              22
#
#                                                     Venue Category
# Neighborhood
# Adelaide, Richmond, King                                       100
# Agincourt                                                        5
# Agincourt North, Steeles East, L'Amoreaux East,...               4
# Alderwood, Long Branch                                          10
# Bayview Village                                                  4
# Bedford Park, Lawrence Manor East                               22
# Berczy Park                                                     56
# Business Reply Mail Processing Centre 969 Eastern               17
# CFB Toronto, Downsview East                                      2
# Caledonia-Fairbanks                                              5
# Canada Post Gateway Processing Centre                           10
# Cedarbrae                                                        8
# Central Bay Street                                              86
# Christie                                                        18
# Church and Wellesley                                            86
# Cliffside West, Birch Cliff                                      4
# Cliffside, Scarborough Village West, Cliffcrest                  3
# Commerce Court, Victoria Hotel                                 100
# Davisville                                                      33
# Davisville North                                                 8
# Design Exchange, Toronto Dominion Centre                       100
# Don Mills North                                                  5
# Don Mills South, Flemingdon Park                                22
# Dovercourt Village, Dufferin                                    17
# Downsview                                                        6
# Downsview Central                                                3
# Downsview North, Wilson Heights, Bathurst Manor                 20
# Downsview Northwest                                              5
# East Toronto                                                     3
# Emery, Humberlea                                                 1
# Exhibition Place, Parkdale Village, Brockton                    21
# Fairview, Oriole, Henry Farm                                    62
# Forest Hill West, Forest Hill North                              4
# Glencairn                                                        4
# Golden Mile, Clairlea, Oakridge                                  9
# Grange Park , Kensington Market, Chinatown                      90
# High Park, The Junction South                                   24
# Highland Creek , Rouge Hill, Port Union                          2
# Hillcrest Village                                                5
# Humber Summit                                                    2
# Humewood-Cedarvale                                               5
# Ionview, Kennedy Park, East Birchmount Park                      7
# Kingsway Park South West, Royal York South West...              14
# L'Amoreaux West                                                 14
# Lawrence Manor, Lawrence Heights                                 8
# Lawrence Park                                                    3
# Leaside                                                         33
# Little Portugal, Trinity–Bellwoods                              55
# Malvern, Rouge                                                   2
# Markland Wood, Old Burnhamthorpe, Bloordale Gar...               7
# Mimico South, New Toronto, Humber Bay Shores                    13
# Morningside, Guildwood, West Hill                                7
# Mount Olive-Silverstone-Jamestown, South Steele...               9
# North Toronto West                                              21
# Northwest                                                        2
# Northwood Park, York University                                  5
# Old Mill, Sunnylea, Kingsway Park South East, F...               1
# Parkdale, Roncesvalles                                          13
# Parkwoods                                                        3
# Princess Gardens, West Deane Park, Martin Grove...               1
# Queen's Park                                                    38
# Regent Park                                                     48
# Richview Gardens, Kingsview Village, St. Philli...               4
# Riverdale, The Danforth West                                    42
# Rosedale                                                         4
# Roselawn                                                         2
# Ryerson, Garden District                                       100
# Scarborough Town Centre, Wexford Heights, Dorse...               6
# Scarborough Village                                              2
# Silver Hills, York Mills                                         1
# Silverthorn, Mount Dennis, Keelesdale, Del Ray                   5
# South Niagara, Bathurst Quay, King and Spadina,...              16
# St. James Town                                                 100
# St. James Town, Cabbagetown                                     44
# Stn A PO Boxes 25 The Esplanade                                 97
# Studio District                                                 41
# Sullivan, Tam O'Shanter – Sullivan, Clarks Corners              11
# Summerhill East, Moore Park                                      4
# Summerhill West, Forest Hill SE, Deer Park, Sou...              16
# Swansea, Runnymede                                              33
# The Beaches                                                      4
# The Beaches West, India Bazaar                                  22
# The Junction North, Runnymede                                    4
# The Kingsway, Montgomery Road, Old Mill North                    3
# Thorncliffe Park                                                18
# Underground city, First Canadian Place                         100
# Union Station , Harbourfront East, Toronto Islands             100
# University of Toronto, Harbord                                  38
# Upwood Park, North Park, Downsview                               5
# Victoria Village                                                 4
# Westmount                                                        7
# Weston                                                           1
# Wexford, Maryvale                                                4
# Willowdale South                                                35
# Willowdale West                                                  6
# Woburn                                                           4
# Woodbine Gardens, Parkview Hill                                 12
# Woodbine Heights                                                11
# York Mills West                                                  4
# Yorkville, The Annex, North Midtown                             22

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 274 uniques categories.

# %%
dfIndian = toronto_venues[toronto_venues['Venue Category'] == 'Indian Restaurant']

# %%
print (dfIndian['Neighborhood'].value_counts())
# Out:
# Scarborough Town Centre, Wexford Heights, Dorset Park    2
# Thorncliffe Park                                         2
# Central Bay Street                                       1
# St. James Town                                           1
# Riverdale, The Danforth West                             1
# Yorkville, The Annex, North Midtown                      1
# Davisville                                               1
# Union Station , Harbourfront East, Toronto Islands       1
# Church and Wellesley                                     1
# St. James Town, Cabbagetown                              1
# Bedford Park, Lawrence Manor East                        1
# Name: Neighborhood, dtype: int64

# %%
dfIndian
# Out:
#                                            Neighborhood  \
# 327                                      St. James Town
# 551                                  Central Bay Street
# 619                                    Thorncliffe Park
# 627                                    Thorncliffe Park
# 901   Union Station , Harbourfront East, Toronto Isl...
# 1023                       Riverdale, The Danforth West
# 1351                  Bedford Park, Lawrence Manor East
# 1430  Scarborough Town Centre, Wexford Heights, Dors...
# 1434  Scarborough Town Centre, Wexford Heights, Dors...
# 1515                Yorkville, The Annex, North Midtown
# 1571                                         Davisville
# 1964                        St. James Town, Cabbagetown
# 2147                               Church and Wellesley
#
#       Neighborhood Latitude  Neighborhood Longitude  \
# 327               43.651494              -79.375418
# 551               43.657952              -79.387383
# 619               43.705369              -79.349372
# 627               43.705369              -79.349372
# 901               43.640816              -79.381752
# 1023              43.679557              -79.352188
# 1351              43.733283              -79.419750
# 1430              43.757410              -79.273304
# 1434              43.757410              -79.273304
# 1515              43.672710              -79.405678
# 1571              43.704324              -79.388790
# 1964              43.667967              -79.367675
# 2147              43.665860              -79.383160
#
#                                             Venue  Venue Latitude  \
# 327                                 Bombay Palace       43.651174
# 551                               Colaba Junction       43.660940
# 619                    Iqbal Kebab & Sweet Centre       43.705923
# 627                                  Hakka Garden       43.704578
# 901                             Indian Roti House       43.639060
# 1023                                Sher-E-Punjab       43.677308
# 1351                           The Copper Chimney       43.736195
# 1430                                      Kairali       43.754915
# 1434  Karaikudi Chettinad South Indian Restaurant       43.756042
# 1515                        Roti Cuisine of India       43.674618
# 1571                       Marigold Indian Bistro       43.702881
# 1964                       Butter Chicken Factory       43.667072
# 2147                        Kothur Indian Cuisine       43.667872
#
#       Venue Longitude     Venue Category
# 327        -79.372140  Indian Restaurant
# 551        -79.385635  Indian Restaurant
# 619        -79.351521  Indian Restaurant
# 627        -79.349770  Indian Restaurant
# 901        -79.385422  Indian Restaurant
# 1023       -79.353066  Indian Restaurant
# 1351       -79.420271  Indian Restaurant
# 1430       -79.276945  Indian Restaurant
# 1434       -79.276276  Indian Restaurant
# 1515       -79.408249  Indian Restaurant
# 1571       -79.388008  Indian Restaurant
# 1964       -79.369184  Indian Restaurant
# 2147       -79.385659  Indian Restaurant

# %%
dfMerged = pd.merge(dfIndian, toronto_data, on="Neighborhood")

# %%
dfMerged
# Out:
#                                          Neighborhood  Neighborhood Latitude  \
# 0                                      St. James Town              43.651494
# 1                                  Central Bay Street              43.657952
# 2                                    Thorncliffe Park              43.705369
# 3                                    Thorncliffe Park              43.705369
# 4   Union Station , Harbourfront East, Toronto Isl...              43.640816
# 5                        Riverdale, The Danforth West              43.679557
# 6                   Bedford Park, Lawrence Manor East              43.733283
# 7   Scarborough Town Centre, Wexford Heights, Dors...              43.757410
# 8   Scarborough Town Centre, Wexford Heights, Dors...              43.757410
# 9                 Yorkville, The Annex, North Midtown              43.672710
# 10                                         Davisville              43.704324
# 11                        St. James Town, Cabbagetown              43.667967
# 12                               Church and Wellesley              43.665860
#
#     Neighborhood Longitude                                        Venue  \
# 0               -79.375418                                Bombay Palace
# 1               -79.387383                              Colaba Junction
# 2               -79.349372                   Iqbal Kebab & Sweet Centre
# 3               -79.349372                                 Hakka Garden
# 4               -79.381752                            Indian Roti House
# 5               -79.352188                                Sher-E-Punjab
# 6               -79.419750                           The Copper Chimney
# 7               -79.273304                                      Kairali
# 8               -79.273304  Karaikudi Chettinad South Indian Restaurant
# 9               -79.405678                        Roti Cuisine of India
# 10              -79.388790                       Marigold Indian Bistro
# 11              -79.367675                       Butter Chicken Factory
# 12              -79.383160                        Kothur Indian Cuisine
#
#     Venue Latitude  Venue Longitude     Venue Category Postcode  \
# 0        43.651174       -79.372140  Indian Restaurant      M5C
# 1        43.660940       -79.385635  Indian Restaurant      M5G
# 2        43.705923       -79.351521  Indian Restaurant      M4H
# 3        43.704578       -79.349770  Indian Restaurant      M4H
# 4        43.639060       -79.385422  Indian Restaurant      M5J
# 5        43.677308       -79.353066  Indian Restaurant      M4K
# 6        43.736195       -79.420271  Indian Restaurant      M5M
# 7        43.754915       -79.276945  Indian Restaurant      M1P
# 8        43.756042       -79.276276  Indian Restaurant      M1P
# 9        43.674618       -79.408249  Indian Restaurant      M5R
# 10       43.702881       -79.388008  Indian Restaurant      M4S
# 11       43.667072       -79.369184  Indian Restaurant      M4X
# 12       43.667872       -79.385659  Indian Restaurant      M4Y
#
#                  Borough   Latitude  Longitude
# 0       Downtown Toronto  43.651494 -79.375418
# 1       Downtown Toronto  43.657952 -79.387383
# 2              East York  43.705369 -79.349372
# 3              East York  43.705369 -79.349372
# 4       Downtown Toronto  43.640816 -79.381752
# 5           East Toronto  43.679557 -79.352188
# 6             North York  43.733283 -79.419750
# 7   Scarborough, Toronto  43.757410 -79.273304
# 8   Scarborough, Toronto  43.757410 -79.273304
# 9        Central Toronto  43.672710 -79.405678
# 10       Central Toronto  43.704324 -79.388790
# 11      Downtown Toronto  43.667967 -79.367675
# 12      Downtown Toronto  43.665860 -79.383160

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(dfMerged['Latitude'], dfMerged['Longitude'], dfMerged['Borough'], dfMerged['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !conda install -c conda-forge wikipedia --yes
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - wikipedia
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     wikipedia-1.4.0            |             py_2          13 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         162 KB
#
# The following NEW packages will be INSTALLED:
#
#     wikipedia: 1.4.0-py_2        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:   2019.11.28-py36_0 anaconda    --> 2019.11.28-py36_0 conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:   1.1.1-h7b6447c_0  anaconda    --> 1.1.1d-h516909a_0 conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# wikipedia-1.4.0      | 13 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
#overall population distribution 
import wikipedia as wp
html = wp.page("Demographics of Toronto").html().encode("UTF-8")

# %%
TEY_population_df = pd.read_html(html, header = 0)[13]
TEY_population_df = TEY_population_df.rename(columns={'%':'Ethnic Origin 1 in %', 
                                                      '%.1':'Ethnic Origin 2 in %',
                                                     '%.2':'Ethnic Origin 3 in %',
                                                     '%.3':'Ethnic Origin 4 in %',
                                                     '%.4':'Ethnic Origin 5 in %',
                                                     '%.5':'Ethnic Origin 6 in %',
                                                     '%.6':'Ethnic Origin 7 in %',
                                                     '%.7':'Ethnic Origin 8 in %',
                                                     '%.8':'Ethnic Origin 9 in %'})
TEY_population_df
# Out:
#                 Riding  Population Ethnic Origin #1  Ethnic Origin 1 in %  \
# 0    Spadina-Fort York      114315          English                  16.4
# 1    Beaches-East York      108435          English                  24.2
# 2            Davenport      107395       Portuguese                  22.7
# 3   Parkdale-High Park      106445          English                  22.3
# 4     Toronto-Danforth      105395          English                  22.9
# 5   Toronto-St. Paul's      104940          English                  18.5
# 6  University-Rosedale      100520          English                  20.6
# 7       Toronto Centre       99590          English                  15.7
#
#   Ethnic Origin #2  Ethnic Origin 2 in % Ethnic Origin #3  \
# 0          Chinese                  16.0            Irish
# 1            Irish                  19.9         Canadian
# 2          English                  13.6         Canadian
# 3            Irish                  20.0         Scottish
# 4            Irish                  19.5         Scottish
# 5         Canadian                  16.1            Irish
# 6            Irish                  16.6         Scottish
# 7         Canadian                  13.7            Irish
#
#    Ethnic Origin 3 in % Ethnic Origin #4  Ethnic Origin 4 in %  \
# 0                  14.6         Canadian                  14.0
# 1                  19.7         Scottish                  18.9
# 2                  12.8            Irish                  11.5
# 3                  18.7         Canadian                  16.1
# 4                  18.7         Canadian                  18.4
# 5                  15.2         Scottish                  14.8
# 6                  16.3         Canadian                  15.2
# 7                  13.4         Scottish                  12.6
#
#   Ethnic Origin #5  Ethnic Origin 5 in % Ethnic Origin #6  \
# 0         Scottish                  13.2           French
# 1           French                   8.7           German
# 2          Italian                  11.1         Scottish
# 3           German                   9.8           French
# 4          Chinese                  13.8           French
# 5           Polish                  10.3           German
# 6          Chinese                  14.7           German
# 7          Chinese                  12.5           French
#
#    Ethnic Origin 6 in % Ethnic Origin #7  Ethnic Origin 7 in %  \
# 0                  7.70           German                   7.6
# 1                  8.40              NaN                   NaN
# 2                 11.00              NaN                   NaN
# 3                  8.88           Polish                   8.5
# 4                  8.86           German                   8.8
# 5                  7.90          Russian                   7.7
# 6                  8.70           French                   7.7
# 7                  7.20              NaN                   NaN
#
#   Ethnic Origin #8  Ethnic Origin 8 in % Ethnic Origin #9  \
# 0              NaN                   NaN              NaN
# 1              NaN                   NaN              NaN
# 2              NaN                   NaN              NaN
# 3              NaN                   NaN              NaN
# 4            Greek                   7.3              NaN
# 5          Italian                   7.3           French
# 6          Italian                   7.4              NaN
# 7              NaN                   NaN              NaN
#
#    Ethnic Origin 9 in %
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   7.2
# 6                   NaN
# 7                   NaN

# %%
#NORTH YORK population distribution by ethnicity 
North_population_df = pd.read_html(html, header = 0)[14]
North_population_df = North_population_df.rename(columns={'%':'Ethnic Origin 1 in %', 
                                                      '%.1':'Ethnic Origin 2 in %',
                                                     '%.2':'Ethnic Origin 3 in %',
                                                     '%.3':'Ethnic Origin 4 in %',
                                                     '%.4':'Ethnic Origin 5 in %',
                                                     '%.5':'Ethnic Origin 6 in %',
                                                     '%.6':'Ethnic Origin 7 in %',
                                                     '%.7':'Ethnic Origin 8 in %'})
North_population_df
# Out:
#                      Riding  Population Ethnic Origin #1  \
# 0                Willowdale      117405          Chinese
# 1         Eglinton-Lawrence      112925         Canadian
# 2          Don Valley North      109060          Chinese
# 3  Humber River-Black Creek      107725          Italian
# 4               York Centre      103760         Filipino
# 5           Don Valley West      101790          English
# 6           Don Valley East       93170      East Indian
#
#    Ethnic Origin 1 in % Ethnic Origin #2  Ethnic Origin 2 in %  \
# 0                  25.9          Iranian                  12.1
# 1                  14.7          English                  12.6
# 2                  32.4      East Indian                   7.3
# 3                  12.8      East Indian                   9.2
# 4                  17.0          Italian                  13.4
# 5                  19.2         Canadian                  15.1
# 6                  10.6         Canadian                  10.4
#
#   Ethnic Origin #3  Ethnic Origin 3 in % Ethnic Origin #4  \
# 0           Korean                  10.6              NaN
# 1           Polish                  12.0         Filipino
# 2          Iranian                   7.3              NaN
# 3         Jamaican                   8.5       Vietnamese
# 4          Russian                   9.5         Canadian
# 5         Scottish                  14.9            Irish
# 6          English                  10.1          Chinese
#
#    Ethnic Origin 4 in % Ethnic Origin #5  Ethnic Origin 5 in %  \
# 0                   NaN              NaN                   NaN
# 1                  11.0         Scottish                   9.7
# 2                   NaN              NaN                   NaN
# 3                   8.0         Canadian                   7.4
# 4                   8.6              NaN                   NaN
# 5                  14.2          Chinese                  11.2
# 6                   8.9            Irish                   8.1
#
#   Ethnic Origin #6  Ethnic Origin 6 in % Ethnic Origin #7  \
# 0              NaN                   NaN              NaN
# 1          Italian                   9.5            Irish
# 2              NaN                   NaN              NaN
# 3              NaN                   NaN              NaN
# 4              NaN                   NaN              NaN
# 5              NaN                   NaN              NaN
# 6         Scottish                   8.0         Filipino
#
#    Ethnic Origin 7 in % Ethnic Origin #8  Ethnic Origin 8 in %
# 0                   NaN              NaN                   NaN
# 1                   9.2          Russian                   8.4
# 2                   NaN              NaN                   NaN
# 3                   NaN              NaN                   NaN
# 4                   NaN              NaN                   NaN
# 5                   NaN              NaN                   NaN
# 6                   7.8              NaN                   NaN

# %%
#SCARBOROUGH population distribution by ethnicity 
Scar_population_df = pd.read_html(html, header = 0)[15]
Scar_population_df = Scar_population_df.rename(columns={'%':'Ethnic Origin 1 in %', 
                                                      '%.1':'Ethnic Origin 2 in %',
                                                     '%.2':'Ethnic Origin 3 in %',
                                                     '%.3':'Ethnic Origin 4 in %',
                                                     '%.4':'Ethnic Origin 5 in %',
                                                     '%.5':'Ethnic Origin 6 in %',
                                                     '%.6':'Ethnic Origin 7 in %',
                                                     '%.7':'Ethnic Origin 8 in %'})
Scar_population_df
# Out:
#                    Riding  Population Ethnic Origin #1  Ethnic Origin 1 in %  \
# 0      Scarborough Centre      110450         Filipino                  13.1
# 1   Scarborough Southwest      108295         Canadian                  16.2
# 2   Scarborough-Agincourt      104225          Chinese                  47.0
# 3  Scarborough-Rouge Park      101445      East Indian                  16.7
# 4   Scarborough-Guildwood      101115      East Indian                  18.0
# 5       Scarborough North       97610          Chinese                  46.6
#
#   Ethnic Origin #2  Ethnic Origin 2 in % Ethnic Origin #3  \
# 0      East Indian                  12.2         Canadian
# 1          English                  14.3            Irish
# 2      East Indian                   7.4              NaN
# 3         Canadian                  11.8       Sri Lankan
# 4         Canadian                  11.6          English
# 5      East Indian                  11.8       Sri Lankan
#
#    Ethnic Origin 3 in % Ethnic Origin #4  Ethnic Origin 4 in %  \
# 0                  11.2          Chinese                  10.7
# 1                  11.5         Scottish                  10.9
# 2                   NaN              NaN                   NaN
# 3                  11.1          English                   9.8
# 4                   9.7         Filipino                   8.5
# 5                   9.4              NaN                   NaN
#
#   Ethnic Origin #5  Ethnic Origin 5 in % Ethnic Origin #6  \
# 0          English                   7.8       Sri Lankan
# 1         Filipino                   9.5      East Indian
# 2              NaN                   NaN              NaN
# 3         Filipino                   9.3         Jamaican
# 4       Sri Lankan                   7.8          Chinese
# 5              NaN                   NaN              NaN
#
#    Ethnic Origin 6 in % Ethnic Origin #7  Ethnic Origin 7 in %  \
# 0                   7.0              NaN                   NaN
# 1                   8.2          Chinese                   7.2
# 2                   NaN              NaN                   NaN
# 3                   8.4         Scottish                   7.2
# 4                   7.1         Scottish                   7.0
# 5                   NaN              NaN                   NaN
#
#   Ethnic Origin #8  Ethnic Origin 8 in %
# 0              NaN                   NaN
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3            Irish                   7.0
# 4              NaN                   NaN
# 5              NaN                   NaN

# %%
#ETOBICOKE & YORK population distribution by ethnicity 
ETY_population_df = pd.read_html(html, header = 0)[16]
ETY_population_df = ETY_population_df.rename(columns={'%':'Ethnic Origin 1 in %', 
                                                      '%.1':'Ethnic Origin 2 in %',
                                                     '%.2':'Ethnic Origin 3 in %',
                                                     '%.3':'Ethnic Origin 4 in %',
                                                     '%.4':'Ethnic Origin 5 in %',
                                                     '%.5':'Ethnic Origin 6 in %',
                                                     '%.6':'Ethnic Origin 7 in %',
                                                     '%.7':'Ethnic Origin 8 in %'})
ETY_population_df
# Out:
#                 Riding  Population Ethnic Origin #1  Ethnic Origin 1 in %  \
# 0  Etobicoke-Lakeshore      127520          English                  17.1
# 1      Etobicoke North      116960      East Indian                  22.2
# 2     Etobicoke Centre      116055          Italian                  15.1
# 3    York South-Weston      115130       Portuguese                  14.5
#
#   Ethnic Origin #2  Ethnic Origin 2 in % Ethnic Origin #3  \
# 0         Canadian                  15.9            Irish
# 1         Canadian                   7.9              NaN
# 2          English                  14.3         Canadian
# 3          Italian                  12.8         Canadian
#
#    Ethnic Origin 3 in % Ethnic Origin #4  Ethnic Origin 4 in %  \
# 0                  14.4         Scottish                  13.5
# 1                   NaN              NaN                   NaN
# 2                  12.1            Irish                  10.8
# 3                   8.7         Jamaican                   8.4
#
#   Ethnic Origin #5  Ethnic Origin 5 in % Ethnic Origin #6  \
# 0           Polish                   9.2          Italian
# 1              NaN                   NaN              NaN
# 2         Scottish                  10.4        Ukrainian
# 3              NaN                   NaN              NaN
#
#    Ethnic Origin 6 in % Ethnic Origin #7  Ethnic Origin 7 in %  \
# 0                   9.1        Ukrainian                   7.6
# 1                   NaN              NaN                   NaN
# 2                   8.1           Polish                   7.4
# 3                   NaN              NaN                   NaN
#
#   Ethnic Origin #8  Ethnic Origin 8 in %
# 0           German                   7.1
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN                   NaN

# %%
ET = ETY_population_df.append(TEY_population_df,sort=True).reset_index()
ET.drop('index',axis=1,inplace=True)
SN = North_population_df.append(Scar_population_df,sort=True).reset_index()
SN.drop('index',axis=1,inplace=True)
pop_ethnic_df = SN.append(ET,sort=True).reset_index()
pop_ethnic_df.drop('index',axis=1,inplace=True)
pop_ethnic_df = pop_ethnic_df[['Riding', 'Population','Ethnic Origin #1', 'Ethnic Origin 1 in %','Ethnic Origin #2', 'Ethnic Origin 2 in %',
                               'Ethnic Origin #3','Ethnic Origin 3 in %','Ethnic Origin #4', 'Ethnic Origin 4 in %','Ethnic Origin #5','Ethnic Origin 5 in %', 
                               'Ethnic Origin #6','Ethnic Origin 6 in %','Ethnic Origin #7', 'Ethnic Origin 7 in %','Ethnic Origin #8', 'Ethnic Origin 8 in %',
                               'Ethnic Origin #9','Ethnic Origin 9 in %',
                              ]]
pop_ethnic_df
# Out:
#                       Riding  Population Ethnic Origin #1  \
# 0                 Willowdale      117405          Chinese
# 1          Eglinton-Lawrence      112925         Canadian
# 2           Don Valley North      109060          Chinese
# 3   Humber River-Black Creek      107725          Italian
# 4                York Centre      103760         Filipino
# 5            Don Valley West      101790          English
# 6            Don Valley East       93170      East Indian
# 7         Scarborough Centre      110450         Filipino
# 8      Scarborough Southwest      108295         Canadian
# 9      Scarborough-Agincourt      104225          Chinese
# 10    Scarborough-Rouge Park      101445      East Indian
# 11     Scarborough-Guildwood      101115      East Indian
# 12         Scarborough North       97610          Chinese
# 13       Etobicoke-Lakeshore      127520          English
# 14           Etobicoke North      116960      East Indian
# 15          Etobicoke Centre      116055          Italian
# 16         York South-Weston      115130       Portuguese
# 17         Spadina-Fort York      114315          English
# 18         Beaches-East York      108435          English
# 19                 Davenport      107395       Portuguese
# 20        Parkdale-High Park      106445          English
# 21          Toronto-Danforth      105395          English
# 22        Toronto-St. Paul's      104940          English
# 23       University-Rosedale      100520          English
# 24            Toronto Centre       99590          English
#
#     Ethnic Origin 1 in % Ethnic Origin #2  Ethnic Origin 2 in %  \
# 0                   25.9          Iranian                  12.1
# 1                   14.7          English                  12.6
# 2                   32.4      East Indian                   7.3
# 3                   12.8      East Indian                   9.2
# 4                   17.0          Italian                  13.4
# 5                   19.2         Canadian                  15.1
# 6                   10.6         Canadian                  10.4
# 7                   13.1      East Indian                  12.2
# 8                   16.2          English                  14.3
# 9                   47.0      East Indian                   7.4
# 10                  16.7         Canadian                  11.8
# 11                  18.0         Canadian                  11.6
# 12                  46.6      East Indian                  11.8
# 13                  17.1         Canadian                  15.9
# 14                  22.2         Canadian                   7.9
# 15                  15.1          English                  14.3
# 16                  14.5          Italian                  12.8
# 17                  16.4          Chinese                  16.0
# 18                  24.2            Irish                  19.9
# 19                  22.7          English                  13.6
# 20                  22.3            Irish                  20.0
# 21                  22.9            Irish                  19.5
# 22                  18.5         Canadian                  16.1
# 23                  20.6            Irish                  16.6
# 24                  15.7         Canadian                  13.7
#
#    Ethnic Origin #3  Ethnic Origin 3 in % Ethnic Origin #4  \
# 0            Korean                  10.6              NaN
# 1            Polish                  12.0         Filipino
# 2           Iranian                   7.3              NaN
# 3          Jamaican                   8.5       Vietnamese
# 4           Russian                   9.5         Canadian
# 5          Scottish                  14.9            Irish
# 6           English                  10.1          Chinese
# 7          Canadian                  11.2          Chinese
# 8             Irish                  11.5         Scottish
# 9               NaN                   NaN              NaN
# 10       Sri Lankan                  11.1          English
# 11          English                   9.7         Filipino
# 12       Sri Lankan                   9.4              NaN
# 13            Irish                  14.4         Scottish
# 14              NaN                   NaN              NaN
# 15         Canadian                  12.1            Irish
# 16         Canadian                   8.7         Jamaican
# 17            Irish                  14.6         Canadian
# 18         Canadian                  19.7         Scottish
# 19         Canadian                  12.8            Irish
# 20         Scottish                  18.7         Canadian
# 21         Scottish                  18.7         Canadian
# 22            Irish                  15.2         Scottish
# 23         Scottish                  16.3         Canadian
# 24            Irish                  13.4         Scottish
#
#     Ethnic Origin 4 in % Ethnic Origin #5  Ethnic Origin 5 in %  \
# 0                    NaN              NaN                   NaN
# 1                   11.0         Scottish                   9.7
# 2                    NaN              NaN                   NaN
# 3                    8.0         Canadian                   7.4
# 4                    8.6              NaN                   NaN
# 5                   14.2          Chinese                  11.2
# 6                    8.9            Irish                   8.1
# 7                   10.7          English                   7.8
# 8                   10.9         Filipino                   9.5
# 9                    NaN              NaN                   NaN
# 10                   9.8         Filipino                   9.3
# 11                   8.5       Sri Lankan                   7.8
# 12                   NaN              NaN                   NaN
# 13                  13.5           Polish                   9.2
# 14                   NaN              NaN                   NaN
# 15                  10.8         Scottish                  10.4
# 16                   8.4              NaN                   NaN
# 17                  14.0         Scottish                  13.2
# 18                  18.9           French                   8.7
# 19                  11.5          Italian                  11.1
# 20                  16.1           German                   9.8
# 21                  18.4          Chinese                  13.8
# 22                  14.8           Polish                  10.3
# 23                  15.2          Chinese                  14.7
# 24                  12.6          Chinese                  12.5
#
#    Ethnic Origin #6  Ethnic Origin 6 in % Ethnic Origin #7  \
# 0               NaN                   NaN              NaN
# 1           Italian                  9.50            Irish
# 2               NaN                   NaN              NaN
# 3               NaN                   NaN              NaN
# 4               NaN                   NaN              NaN
# 5               NaN                   NaN              NaN
# 6          Scottish                  8.00         Filipino
# 7        Sri Lankan                  7.00              NaN
# 8       East Indian                  8.20          Chinese
# 9               NaN                   NaN              NaN
# 10         Jamaican                  8.40         Scottish
# 11          Chinese                  7.10         Scottish
# 12              NaN                   NaN              NaN
# 13          Italian                  9.10        Ukrainian
# 14              NaN                   NaN              NaN
# 15        Ukrainian                  8.10           Polish
# 16              NaN                   NaN              NaN
# 17           French                  7.70           German
# 18           German                  8.40              NaN
# 19         Scottish                 11.00              NaN
# 20           French                  8.88           Polish
# 21           French                  8.86           German
# 22           German                  7.90          Russian
# 23           German                  8.70           French
# 24           French                  7.20              NaN
#
#     Ethnic Origin 7 in % Ethnic Origin #8  Ethnic Origin 8 in %  \
# 0                    NaN              NaN                   NaN
# 1                    9.2          Russian                   8.4
# 2                    NaN              NaN                   NaN
# 3                    NaN              NaN                   NaN
# 4                    NaN              NaN                   NaN
# 5                    NaN              NaN                   NaN
# 6                    7.8              NaN                   NaN
# 7                    NaN              NaN                   NaN
# 8                    7.2              NaN                   NaN
# 9                    NaN              NaN                   NaN
# 10                   7.2            Irish                   7.0
# 11                   7.0              NaN                   NaN
# 12                   NaN              NaN                   NaN
# 13                   7.6           German                   7.1
# 14                   NaN              NaN                   NaN
# 15                   7.4              NaN                   NaN
# 16                   NaN              NaN                   NaN
# 17                   7.6              NaN                   NaN
# 18                   NaN              NaN                   NaN
# 19                   NaN              NaN                   NaN
# 20                   8.5              NaN                   NaN
# 21                   8.8            Greek                   7.3
# 22                   7.7          Italian                   7.3
# 23                   7.7          Italian                   7.4
# 24                   NaN              NaN                   NaN
#
#    Ethnic Origin #9  Ethnic Origin 9 in %
# 0               NaN                   NaN
# 1               NaN                   NaN
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               NaN                   NaN
# 5               NaN                   NaN
# 6               NaN                   NaN
# 7               NaN                   NaN
# 8               NaN                   NaN
# 9               NaN                   NaN
# 10              NaN                   NaN
# 11              NaN                   NaN
# 12              NaN                   NaN
# 13              NaN                   NaN
# 14              NaN                   NaN
# 15              NaN                   NaN
# 16              NaN                   NaN
# 17              NaN                   NaN
# 18              NaN                   NaN
# 19              NaN                   NaN
# 20              NaN                   NaN
# 21              NaN                   NaN
# 22           French                   7.2
# 23              NaN                   NaN
# 24              NaN                   NaN

# %%
#Filtering the riding with Indian ethnic crowd
temp = pop_ethnic_df.loc[(pop_ethnic_df['Ethnic Origin #1'] == 'East Indian')| 
                                      (pop_ethnic_df['Ethnic Origin #2'] == 'East Indian')|
                                      (pop_ethnic_df['Ethnic Origin #3'] == 'East Indian')|
                                      (pop_ethnic_df['Ethnic Origin #4'] == 'East Indian')|
                                      (pop_ethnic_df['Ethnic Origin #5'] == 'East Indian')|
                                      (pop_ethnic_df['Ethnic Origin #6'] == 'East Indian')|
                                      (pop_ethnic_df['Ethnic Origin #7'] == 'East Indian')|
                                      (pop_ethnic_df['Ethnic Origin #8'] == 'East Indian')|
                                      (pop_ethnic_df['Ethnic Origin #9'] == 'East Indian')]
pop_indian_df = pd.DataFrame(temp).reset_index()
pop_indian_df.drop('index',axis=1,inplace=True)

pop_indian_df
# Out:
#                      Riding  Population Ethnic Origin #1  \
# 0          Don Valley North      109060          Chinese
# 1  Humber River-Black Creek      107725          Italian
# 2           Don Valley East       93170      East Indian
# 3        Scarborough Centre      110450         Filipino
# 4     Scarborough Southwest      108295         Canadian
# 5     Scarborough-Agincourt      104225          Chinese
# 6    Scarborough-Rouge Park      101445      East Indian
# 7     Scarborough-Guildwood      101115      East Indian
# 8         Scarborough North       97610          Chinese
# 9           Etobicoke North      116960      East Indian
#
#    Ethnic Origin 1 in % Ethnic Origin #2  Ethnic Origin 2 in %  \
# 0                  32.4      East Indian                   7.3
# 1                  12.8      East Indian                   9.2
# 2                  10.6         Canadian                  10.4
# 3                  13.1      East Indian                  12.2
# 4                  16.2          English                  14.3
# 5                  47.0      East Indian                   7.4
# 6                  16.7         Canadian                  11.8
# 7                  18.0         Canadian                  11.6
# 8                  46.6      East Indian                  11.8
# 9                  22.2         Canadian                   7.9
#
#   Ethnic Origin #3  Ethnic Origin 3 in % Ethnic Origin #4  \
# 0          Iranian                   7.3              NaN
# 1         Jamaican                   8.5       Vietnamese
# 2          English                  10.1          Chinese
# 3         Canadian                  11.2          Chinese
# 4            Irish                  11.5         Scottish
# 5              NaN                   NaN              NaN
# 6       Sri Lankan                  11.1          English
# 7          English                   9.7         Filipino
# 8       Sri Lankan                   9.4              NaN
# 9              NaN                   NaN              NaN
#
#    Ethnic Origin 4 in % Ethnic Origin #5  Ethnic Origin 5 in %  \
# 0                   NaN              NaN                   NaN
# 1                   8.0         Canadian                   7.4
# 2                   8.9            Irish                   8.1
# 3                  10.7          English                   7.8
# 4                  10.9         Filipino                   9.5
# 5                   NaN              NaN                   NaN
# 6                   9.8         Filipino                   9.3
# 7                   8.5       Sri Lankan                   7.8
# 8                   NaN              NaN                   NaN
# 9                   NaN              NaN                   NaN
#
#   Ethnic Origin #6  Ethnic Origin 6 in % Ethnic Origin #7  \
# 0              NaN                   NaN              NaN
# 1              NaN                   NaN              NaN
# 2         Scottish                   8.0         Filipino
# 3       Sri Lankan                   7.0              NaN
# 4      East Indian                   8.2          Chinese
# 5              NaN                   NaN              NaN
# 6         Jamaican                   8.4         Scottish
# 7          Chinese                   7.1         Scottish
# 8              NaN                   NaN              NaN
# 9              NaN                   NaN              NaN
#
#    Ethnic Origin 7 in % Ethnic Origin #8  Ethnic Origin 8 in %  \
# 0                   NaN              NaN                   NaN
# 1                   NaN              NaN                   NaN
# 2                   7.8              NaN                   NaN
# 3                   NaN              NaN                   NaN
# 4                   7.2              NaN                   NaN
# 5                   NaN              NaN                   NaN
# 6                   7.2            Irish                   7.0
# 7                   7.0              NaN                   NaN
# 8                   NaN              NaN                   NaN
# 9                   NaN              NaN                   NaN
#
#   Ethnic Origin #9  Ethnic Origin 9 in %
# 0              NaN                   NaN
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN                   NaN
# 4              NaN                   NaN
# 5              NaN                   NaN
# 6              NaN                   NaN
# 7              NaN                   NaN
# 8              NaN                   NaN
# 9              NaN                   NaN

# %%
#retaining only Indian ethnic percentage & the neighborhood name 
columns_list = pop_indian_df.columns.to_list()
pop_indian_DF_with_percent = pd.DataFrame()
#removing Riding & Population from the column names list
del columns_list[0]
del columns_list[0]


for i in range(0,pop_indian_df.shape[0]):
    for j in columns_list:
        print(j)
        if pop_indian_df.at[i, j] == 'East Indian':
            k = columns_list.index(j) + 1
            percent_col = columns_list[k]
            pop_indian_DF_with_percent = pop_indian_DF_with_percent.append({'Riding':pop_indian_df.at[i, 'Riding'], 'Population':pop_indian_df.at[i, 'Population']
                                                                           , 'Ethnicity': pop_indian_df.at[i, j], 'Percentage': pop_indian_df.at[i, percent_col]},ignore_index=True)

pop_indian_DF_with_percent
# Out:
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
# Ethnic Origin #1
# Ethnic Origin 1 in %
# Ethnic Origin #2
# Ethnic Origin 2 in %
# Ethnic Origin #3
# Ethnic Origin 3 in %
# Ethnic Origin #4
# Ethnic Origin 4 in %
# Ethnic Origin #5
# Ethnic Origin 5 in %
# Ethnic Origin #6
# Ethnic Origin 6 in %
# Ethnic Origin #7
# Ethnic Origin 7 in %
# Ethnic Origin #8
# Ethnic Origin 8 in %
# Ethnic Origin #9
# Ethnic Origin 9 in %
#      Ethnicity  Percentage  Population                    Riding
# 0  East Indian         7.3    109060.0          Don Valley North
# 1  East Indian         9.2    107725.0  Humber River-Black Creek
# 2  East Indian        10.6     93170.0           Don Valley East
# 3  East Indian        12.2    110450.0        Scarborough Centre
# 4  East Indian         8.2    108295.0     Scarborough Southwest
# 5  East Indian         7.4    104225.0     Scarborough-Agincourt
# 6  East Indian        16.7    101445.0    Scarborough-Rouge Park
# 7  East Indian        18.0    101115.0     Scarborough-Guildwood
# 8  East Indian        11.8     97610.0         Scarborough North
# 9  East Indian        22.2    116960.0           Etobicoke North

# %%
pop_indian_DF_with_percent['Indian Population'] = (pop_indian_DF_with_percent['Percentage'] * pop_indian_DF_with_percent['Population'])/100
pop_indian_DF_with_percent.drop(columns={'Percentage','Population','Ethnicity'},axis=1, inplace =True)
pop_indian_DF_with_percent.drop_duplicates(keep='first',inplace=True) 
pop_indian_DF_with_percent
# Out:
#                      Riding  Indian Population
# 0          Don Valley North           7961.380
# 1  Humber River-Black Creek           9910.700
# 2           Don Valley East           9876.020
# 3        Scarborough Centre          13474.900
# 4     Scarborough Southwest           8880.190
# 5     Scarborough-Agincourt           7712.650
# 6    Scarborough-Rouge Park          16941.315
# 7     Scarborough-Guildwood          18200.700
# 8         Scarborough North          11517.980
# 9           Etobicoke North          25965.120

# %%
bar_graph = pop_indian_DF_with_percent.sort_values(by='Indian Population', ascending=False)
bar_graph.plot(kind='bar',x='Riding', y='Indian Population',figsize=(12,8), color='blue')
plt.title("Indian Population in each Neighborhood")
plt.xlabel("Neighborhoods")
plt.ylabel("Population")
plt.show()

# %%
#Altering the list to match the wikipedia page so we can retrieve the neighborhoods present in those Ridings
riding_list = pop_indian_DF_with_percent['Riding'].to_list()
riding_list[riding_list.index('Scarborough Centre')] = 'Scarborough Centre (electoral district)'
riding_list[riding_list.index('Scarborough North')] = 'Scarborough North (electoral district)'
riding_list
# Out:
# ['Don Valley North',
#  'Humber River-Black Creek',
#  'Don Valley East',
#  'Scarborough Centre (electoral district)',
#  'Scarborough Southwest',
#  'Scarborough-Agincourt',
#  'Scarborough-Rouge Park',
#  'Scarborough-Guildwood',
#  'Scarborough North (electoral district)',
#  'Etobicoke North']

# %%
#Scraping wiki page to get the neighborhoods of ech Ridings
import wikipedia

Riding_neighborhood_df = pd.DataFrame()

for item in riding_list:
    section = wikipedia.WikipediaPage(item).section('Geography')
    start = section.index('neighbourhoods of') + 17
    stop = section.index('.',start)
    Riding_neighborhood_df = Riding_neighborhood_df.append({'Riding':item, 'Neighborhood':section[start:stop]},ignore_index=True)
    

Riding_neighborhood_df = Riding_neighborhood_df[['Riding','Neighborhood']]
Riding_neighborhood_df
# Out:
#                                     Riding  \
# 0                         Don Valley North
# 1                 Humber River-Black Creek
# 2                          Don Valley East
# 3  Scarborough Centre (electoral district)
# 4                    Scarborough Southwest
# 5                    Scarborough-Agincourt
# 6                   Scarborough-Rouge Park
# 7                    Scarborough-Guildwood
# 8   Scarborough North (electoral district)
# 9                          Etobicoke North
#
#                                         Neighborhood
# 0   Henry Farm, Bayview Village, Bayview Woods-St...
# 1   Humber Summit, Humbermede, Humberlea, York Un...
# 2   Flemingdon Park, Don Mills, Graydon Hall, Par...
# 3   Scarborough City Centre (west of McCowan Road...
# 4   Birch Cliff, Oakridge, Cliffside, Kennedy Par...
# 5   Steeles, L'Amoreaux, Tam O'Shanter-Sullivan, ...
# 6   Morningside Heights, Rouge, Port Union, West ...
# 7   Guildwood, West Hill (west of Morningside Ave...
# 8   Agincourt (east of Midland Avenue), Milliken ...
# 9   The Elms, Humberwood, Kingsview Village, This...

# %%
dfRidingNeighMerged = pd.merge(Riding_neighborhood_df, pop_indian_DF_with_percent, on="Riding")

# %%
dfRidingNeighMerged
# Out:
#                      Riding  \
# 0          Don Valley North
# 1  Humber River-Black Creek
# 2           Don Valley East
# 3     Scarborough Southwest
# 4     Scarborough-Agincourt
# 5    Scarborough-Rouge Park
# 6     Scarborough-Guildwood
# 7           Etobicoke North
#
#                                         Neighborhood  Indian Population
# 0   Henry Farm, Bayview Village, Bayview Woods-St...           7961.380
# 1   Humber Summit, Humbermede, Humberlea, York Un...           9910.700
# 2   Flemingdon Park, Don Mills, Graydon Hall, Par...           9876.020
# 3   Birch Cliff, Oakridge, Cliffside, Kennedy Par...           8880.190
# 4   Steeles, L'Amoreaux, Tam O'Shanter-Sullivan, ...           7712.650
# 5   Morningside Heights, Rouge, Port Union, West ...          16941.315
# 6   Guildwood, West Hill (west of Morningside Ave...          18200.700
# 7   The Elms, Humberwood, Kingsview Village, This...          25965.120

# %%
#Merging the pop_indian_DF_with_percent dataframe containing population information with the Riding_neighborhood_df dataframe.

Neigh_pop = pd.merge(pop_indian_DF_with_percent, Riding_neighborhood_df, on='Riding')

# %%
Neigh_pop.sort_values(by='Indian Population', ascending=False)
# Out:
#                      Riding  Indian Population  \
# 7           Etobicoke North          25965.120
# 6     Scarborough-Guildwood          18200.700
# 5    Scarborough-Rouge Park          16941.315
# 1  Humber River-Black Creek           9910.700
# 2           Don Valley East           9876.020
# 3     Scarborough Southwest           8880.190
# 0          Don Valley North           7961.380
# 4     Scarborough-Agincourt           7712.650
#
#                                         Neighborhood
# 7   The Elms, Humberwood, Kingsview Village, This...
# 6   Guildwood, West Hill (west of Morningside Ave...
# 5   Morningside Heights, Rouge, Port Union, West ...
# 1   Humber Summit, Humbermede, Humberlea, York Un...
# 2   Flemingdon Park, Don Mills, Graydon Hall, Par...
# 3   Birch Cliff, Oakridge, Cliffside, Kennedy Par...
# 0   Henry Farm, Bayview Village, Bayview Woods-St...
# 4   Steeles, L'Amoreaux, Tam O'Shanter-Sullivan, ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### Etobicoke North has the highest Indian Population in Toronto but no Indian Restaurtant as per the Foursquare data. Hence, opening an Indian Restaurant in the Etobicoke North riding will make a lot of sense.
